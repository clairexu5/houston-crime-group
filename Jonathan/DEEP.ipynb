# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Crime_DataSet.csv")

# %%
df.head(30)
# Out:
#                         Location_Desc Police_Beat Street_Type  RecordID  \
# 0                                 NaN       14D40          RD         1
# 1                                 NaN        7C20         NaN         2
# 2                                 NaN       13D40        PKWY         3
# 3                                 NaN       18F40          RD         4
# 4                RESTAURANT/CAFETERIA       24C60        PKWY         5
# 5       MISC. BUSINESS (NON-SPECIFIC)       18F60        BLVD         6
# 6                                 NaN       12D20         FWY         7
# 7                   OTHER PARKING LOT        3B10         NaN         8
# 8               APARTMENT PARKING LOT        5F10          DR         9
# 9                     OFFICE BUILDING        1A20         NaN        10
# 10                      OTHER/UNKNOWN       11H10         NaN        11
# 11            RENTAL STORAGE FACILITY       19G20          ST        12
# ...

# %%
df.count()
# Out:
# Location_Desc      1058263
# Police_Beat        1090899
# Street_Type         832422
# RecordID           1094207
# Date_Reported      1094203
# Offense_Type       1094207
# Block_Range        1094050
# Street_Prefix       150422
# Street_Name        1094205
# Num_Offenses       1094207
# Srce_YYMM          1094207
# NGC                 242420
# Match_addr         1063260
# X                  1080683
# Y                  1080683
# GEOID10            1063260
# GEOID00            1063260
# Police_Division    1051759
# CTA_ID             1049989
# CTA_Name           1049989
# Geocoded           1094207
# Location_Code      1058200
# Hour               1094207
# dtype: int64

# %%
df.groupby("Offense_Type").count()
# Out:
#                     Location_Desc  Police_Beat  Street_Type  RecordID  \
# Offense_Type
# 1                              12           13           10        14
# Aggravated Assault          86607        89667        65834     90075
# Auto Theft                 105186       108832        83660    109185
# Burglary                   196460       200155       153367    200450
# Murder                       1989         2075         1556      2088
# Rape                         7264         7525         5532      7622
# Robbery                     81698        83521        65829     83792
# Theft                      579047       599111       456634    600981
#
#                     Date_Reported  Block_Range  Street_Prefix  Street_Name  \
# Offense_Type
# 1                              14           14              3           14
# Aggravated Assault          90075        90075          10011        90074
# Auto Theft                 109185       109178          12721       109185
# ...

# %%
df.groupby("Location_Desc").count()
# Out:
#                                                     Police_Beat  Street_Type  \
# Location_Desc
# ADULT BOOK STORE/NEWSSTAND                                  247          212
# ADULT NOVELTY STORE                                          15           12
# ADULT THEATER/ARCADE                                          5            3
# AIRPORT TERMINAL                                           4074         3946
# ALLEY                                                       442          334
# AMUSE. PARK, BOWL. ALLEY, SKATE RINK                        425          367
# APARTMENT                                                125551       101623
# APARTMENT LAUNDRY                                           632          518
# APARTMENT PARKING LOT                                    122131        99024
# APARTMENT/RENTAL OFFICE                                    2151         1766
# AUTO REPAIR                                                3022         2450
# ...

# %%
type(df.groupby("Location_Desc").count())
(df.groupby("Offense_Type").count()).Num_Offenses.plot.bar()

# %%
df.groupby("Offense_Type").count().Num_Offenses.sort_values(ascending=False).plot.bar()
